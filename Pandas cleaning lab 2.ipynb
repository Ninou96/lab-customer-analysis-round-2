# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\Users\NIDHAL\Desktop\Ninou\files_for_lab\csv_files\file1.csv")

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv(r"C:\Users\NIDHAL\Desktop\Ninou\files_for_lab\csv_files\file2.csv")

# %%
df3 = pd.read_csv(r"C:\Users\NIDHAL\Desktop\Ninou\files_for_lab\csv_files\file3.csv")

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
df3.rename(columns={'State':'ST'}, inplace=True)

# %%
df3
# Out:
#      Customer          ST  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
arranged_columns= df3.columns.tolist()

# %%
arranged_columns
# Out:
# ['Customer',
#  'ST',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Total Claim Amount',
#  'Vehicle Class']

# %%
arranged_columns = arranged_columns[-1:] + arranged_columns[:-1]

# %%
arranged_columns
# Out:
# ['Vehicle Class',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Total Claim Amount']

# %%
df3=df3[arranged_columns]

# %%
df3
# Out:
#       Vehicle Class  Customer Lifetime Value             Education Gender  \
# 0      Two-Door Car              3479.137523  High School or Below      M
# 1      Two-Door Car              2502.637401                Master      M
# 2     Four-Door Car              3265.156348              Bachelor      F
# 3               SUV              4455.843406  High School or Below      F
# 4               SUV              7704.958480  High School or Below      M
# ...             ...                      ...                   ...    ...
# 7065  Four-Door Car             23405.987980              Bachelor      M
# 7066  Four-Door Car              3096.511217               College      F
# 7067  Four-Door Car              8163.890428              Bachelor      M
# 7068  Four-Door Car              7524.442436               College      M
# 7069   Two-Door Car              2611.836866               College      M
#
#       Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %%
pdList = [df1, df2, df3]

# %%
new_df = pd.concat(pdList)

# %%
new_df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN              Bachelor
# 7066      NaN         NaN    NaN               College
# 7067      NaN         NaN    NaN              Bachelor
# 7068      NaN         NaN    NaN               College
# 7069      NaN         NaN    NaN               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
new_df._get_numeric_data()
# Out:
#        Income  Monthly Premium Auto  Total Claim Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
new_df.select_dtypes(exclude=["number"]).columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Gender'],
#       dtype='object')

# %%
df_final = new_df.drop(new_df.columns[[3, 7]], axis=1)

# %%
df_final
# Out:
#      Customer          ST GENDER Customer Lifetime Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065      NaN         NaN    NaN             23405.98798  71941.0
# 7066      NaN         NaN    NaN             3096.511217  21604.0
# 7067      NaN         NaN    NaN             8163.890428      0.0
# 7068      NaN         NaN    NaN             7524.442436  21941.0
# 7069      NaN         NaN    NaN             2611.836866      0.0
#
#       Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df_final['Customer Lifetime Value'] = df_final['Customer Lifetime Value'].multiply(100)

# %%
df_final
# Out:
#      Customer          ST GENDER  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 2     AI49188      Nevada      F
# 3     WW63253  California      M
# 4     GA49547  Washington      M
# ...       ...         ...    ...
# 7065      NaN         NaN    NaN
# 7066      NaN         NaN    NaN
# 7067      NaN         NaN    NaN
# 7068      NaN         NaN    NaN
# 7069      NaN         NaN    NaN
#
#                                 Customer Lifetime Value   Income  \
# 0                                                   NaN      0.0
# 1     697953.59%697953.59%697953.59%697953.59%697953...      0.0
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...  48767.0
# 3     764586.18%764586.18%764586.18%764586.18%764586...      0.0
# 4     536307.65%536307.65%536307.65%536307.65%536307...  36357.0
# ...                                                 ...      ...
# 7065                                        2340598.798  71941.0
# ...

# %%
df_final['Customer Lifetime Value'] = df_final['Customer Lifetime Value'].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2315, in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
df_final.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066     True
# 7067    False
# 7068    False
# 7069    False
# Length: 12074, dtype: bool

# %%
df_final.drop_duplicates()
# Out:
#      Customer          ST GENDER  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 2     AI49188      Nevada      F
# 3     WW63253  California      M
# 4     GA49547  Washington      M
# ...       ...         ...    ...
# 7064      NaN         NaN    NaN
# 7065      NaN         NaN    NaN
# 7067      NaN         NaN    NaN
# 7068      NaN         NaN    NaN
# 7069      NaN         NaN    NaN
#
#                                 Customer Lifetime Value   Income  \
# 0                                                   NaN      0.0
# 1     697953.59%697953.59%697953.59%697953.59%697953...      0.0
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...  48767.0
# 3     764586.18%764586.18%764586.18%764586.18%764586...      0.0
# 4     536307.65%536307.65%536307.65%536307.65%536307...  36357.0
# ...                                                 ...      ...
# 7064                                        410039.8533  47761.0
# ...

# %%
mask = df_final["Income"] <= 0

# %%
df_final[mask]
# Out:
#      Customer          ST GENDER  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 3     WW63253  California      M
# 7     CF85061     Arizona      M
# 10    SX51350  California      M
# ...       ...         ...    ...
# 7059      NaN         NaN    NaN
# 7061      NaN         NaN    NaN
# 7062      NaN         NaN    NaN
# 7067      NaN         NaN    NaN
# 7069      NaN         NaN    NaN
#
#                                 Customer Lifetime Value  Income  \
# 0                                                   NaN     0.0
# 1     697953.59%697953.59%697953.59%697953.59%697953...     0.0
# 3     764586.18%764586.18%764586.18%764586.18%764586...     0.0
# 7     721610.03%721610.03%721610.03%721610.03%721610...     0.0
# 10    473899.20%473899.20%473899.20%473899.20%473899...     0.0
# ...                                                 ...     ...
# 7059                                        567805.0167     0.0
# ...

# %%
mask = (df_final.Income <= 0)

# %%
print(mask)
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067     True
# 7068    False
# 7069     True
# Name: Income, Length: 12074, dtype: bool

# %%
df_final
# Out:
#      Customer          ST GENDER  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 2     AI49188      Nevada      F
# 3     WW63253  California      M
# 4     GA49547  Washington      M
# ...       ...         ...    ...
# 7065      NaN         NaN    NaN
# 7066      NaN         NaN    NaN
# 7067      NaN         NaN    NaN
# 7068      NaN         NaN    NaN
# 7069      NaN         NaN    NaN
#
#                                 Customer Lifetime Value   Income  \
# 0                                                   NaN      0.0
# 1     697953.59%697953.59%697953.59%697953.59%697953...      0.0
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...  48767.0
# 3     764586.18%764586.18%764586.18%764586.18%764586...      0.0
# 4     536307.65%536307.65%536307.65%536307.65%536307...  36357.0
# ...                                                 ...      ...
# 7065                                        2340598.798  71941.0
# ...
